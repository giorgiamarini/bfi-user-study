# %%
# !pip3 install pandas
# Out:
# ...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/console.py", line 1305, in render
#     for render_output in iter_render:
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_internal/utils/logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip/_vendor/rich/segment.py", line 249, in split_lines
# ...

# %%
import pandas as pd

# %%
movies = pd.read_csv('cleaned_movies.csv')

# %%
movies.head()
# Out:
#    movie_id                               title releaseDate       directedBy  \
# 0         1                    Toy Story (1995)  1995-11-19    John Lasseter
# 1         2                      Jumanji (1995)  1995-12-15     Joe Johnston
# 2         3             Grumpier Old Men (1995)  1995-01-01    Howard Deutch
# 3         4            Waiting to Exhale (1995)  1996-01-15  Forest Whitaker
# 4         5  Father of the Bride Part II (1995)  1995-12-08    Charles Shyer
#
#                                             starring  imdb_id  tmdb_id  \
# 0  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...   114709    862.0
# 1  Jonathan Hyde, Bradley Pierce, Robin Williams,...   113497   8844.0
# 2  Jack Lemmon, Walter Matthau, Ann-Margret , Sop...   113228  15602.0
# 3  Angela Bassett, Loretta Devine, Whitney Housto...   114885  31357.0
# 4  Steve Martin, Martin Short, Diane Keaton, Kimb...   113041  11862.0
#
#                                         genres
# ...

# %%
pop = pd.read_csv('dict_pop.csv')

# %%
pop.head()
# Out:
#    movie  popularity
# 0      1    0.647802
# 1      2    0.319780
# 2      3    0.064286
# 3      5    0.080220
# 4      6    0.262088

# %%
movies_pop = pd.merge(movies, pop, how='inner', left_on = 'movie_id', right_on = 'movie')

# %%
movies_pop.head()
# Out:
#    movie_id                               title releaseDate       directedBy  \
# 0         1                    Toy Story (1995)  1995-11-19    John Lasseter
# 1         2                      Jumanji (1995)  1995-12-15     Joe Johnston
# 2         3             Grumpier Old Men (1995)  1995-01-01    Howard Deutch
# 3         4            Waiting to Exhale (1995)  1996-01-15  Forest Whitaker
# 4         5  Father of the Bride Part II (1995)  1995-12-08    Charles Shyer
#
#                                             starring  imdb_id  tmdb_id  \
# 0  Tim Allen, Tom Hanks, Don Rickles, Jim Varney,...   114709    862.0
# 1  Jonathan Hyde, Bradley Pierce, Robin Williams,...   113497   8844.0
# 2  Jack Lemmon, Walter Matthau, Ann-Margret , Sop...   113228  15602.0
# 3  Angela Bassett, Loretta Devine, Whitney Housto...   114885  31357.0
# 4  Steve Martin, Martin Short, Diane Keaton, Kimb...   113041  11862.0
#
#                                         genres  movie  popularity
# ...

# %%
movies_pop.sort_values(by=['popularity'], inplace=True, ascending=False)

# %%
final = movies_pop.head()

# %%
final
# Out:
#       movie_id                                              title releaseDate  \
# 2227      2571                                 Matrix, The (1999)  1999-03-31
# 9055     79132                                   Inception (2010)  2010-07-16
# 336        356                                Forrest Gump (1994)  1994-07-06
# 4375      4993  Lord of the Rings: The Fellowship of the Ring,...  2001-12-19
# 2578      2959                                  Fight Club (1999)  1999-10-15
#
#                            directedBy  \
# 2227  Andy Wachowski, Larry Wachowski
# 9055                Christopher Nolan
# 336                   Robert Zemeckis
# 4375                    Peter Jackson
# 2578                    David Fincher
#
#                                                starring  imdb_id  tmdb_id  \
# 2227  Laurence Fishburne, Keanu Reeves, Hugo Weaving...   133093    603.0
# 9055  Leonardo DiCaprio, Ken Watanabe, Joseph Gordon...  1375666  27205.0
# ...
